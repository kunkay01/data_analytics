# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3463, 276)
#    type        id        lat       lon tags.addr:city tags.addr:country  \
# 0  node  33126515  47.155616  9.037915        Schänis                CH
# 1  node  36726161  47.226191  8.980329         Uznach               NaN
# 2  node  39768209  47.225154  8.969868         Uznach               NaN
# 3  node  39947904  47.376732  8.542161         Zürich                CH
# 4  node  48932835  47.375020  8.522895         Zürich               NaN
#
#   tags.addr:housenumber tags.addr:postcode tags.addr:street tags.brand  ...  \
# 0                    32               8718   Biltnerstrasse       Spar  ...
# 1                    25               8730   Zürcherstrasse     Migros  ...
# 2                   NaN               8730              NaN       Coop  ...
# 3                     1               8001    Bahnhofbrücke       Coop  ...
# 4                     7               8004     Wengistrasse     Migros  ...
#
#   tags.postid tags.diet:local tags.payment:account_cards  \
# 0         NaN             NaN                        NaN
# 1         NaN             NaN                        NaN
# 2         NaN             NaN                        NaN
# 3         NaN             NaN                        NaN
# 4         NaN             NaN                        NaN
#
#   tags.diet:mediterranean tags.diet:organic tags.diet:seafood  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
#
#   tags.recycling:low_energy_bulbs tags.image tags.opening_hours:cafe  \
# 0                             NaN        NaN                     NaN
# 1                             NaN        NaN                     NaN
# 2                             NaN        NaN                     NaN
# 3                             NaN        NaN                     NaN
# 4                             NaN        NaN                     NaN
#
#   tags.name:zh-Hans
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 276 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 6  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07f23d1e15bd7ecd2d8ea23976817bfb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07f23d1e15bd7ecd2d8ea23976817bfb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07f23d1e15bd7ecd2d8ea23976817bfb = L.map(
#                 &quot;map_07f23d1e15bd7ecd2d8ea23976817bfb&quot;,
#                 {
#                     center: [47.008612707673265, 8.004337954702969],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_07f23d1e15bd7ecd2d8ea23976817bfb);
#
#
#
#
#
#             var tile_layer_30f5b5340e3d8763fccb613d6f4b14e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_30f5b5340e3d8763fccb613d6f4b14e7.addTo(map_07f23d1e15bd7ecd2d8ea23976817bfb);
#
#
#             var marker_39608c6f08c9403aef483364b5a0467a = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_07f23d1e15bd7ecd2d8ea23976817bfb);
#
#
#         var popup_3e350a919bd4815eb7d40d9d71490e2b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ca971f6febd176bd9f88626eb05d966e = $(`&lt;div id=&quot;html_ca971f6febd176bd9f88626eb05d966e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_3e350a919bd4815eb7d40d9d71490e2b.setContent(html_ca971f6febd176bd9f88626eb05d966e);
#
#
#
#         marker_39608c6f08c9403aef483364b5a0467a.bindPopup(popup_3e350a919bd4815eb7d40d9d71490e2b)
#         ;
#
#
#
#
#             var marker_5d046ff6f1395e54d76a1c5d5d45ddf9 = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_07f23d1e15bd7ecd2d8ea23976817bfb);
#
#
#         var popup_9f6a170bfcb53df09b1132c5bab0c1a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d359556d1a76d236e62ad6b8ffc7a5a = $(`&lt;div id=&quot;html_2d359556d1a76d236e62ad6b8ffc7a5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_9f6a170bfcb53df09b1132c5bab0c1a3.setContent(html_2d359556d1a76d236e62ad6b8ffc7a5a);
#
#
#
#         marker_5d046ff6f1395e54d76a1c5d5d45ddf9.bindPopup(popup_9f6a170bfcb53df09b1132c5bab0c1a3)
#         ;
#
#
#
#
#             var marker_6d3341185e956a24bbcc58d32067d5a2 = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_07f23d1e15bd7ecd2d8ea23976817bfb);
#
#
#         var popup_328b5c01d1d7a4621f51096c54de060a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8866324b5426bf137e69fc87dd396f1f = $(`&lt;div id=&quot;html_8866324b5426bf137e69fc87dd396f1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_328b5c01d1d7a4621f51096c54de060a.setContent(html_8866324b5426bf137e69fc87dd396f1f);
#
#
#
#         marker_6d3341185e956a24bbcc58d32067d5a2.bindPopup(popup_328b5c01d1d7a4621f51096c54de060a)
#         ;
#
#
#
#
#             var marker_90a220280f067cc23fb5e3de3db8eec6 = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_07f23d1e15bd7ecd2d8ea23976817bfb);
#
#
#         var popup_581d76ae58dbd000c835a73874e58c76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_270e9f4dbe7685c6c425e4df7a1c91e9 = $(`&lt;div id=&quot;html_270e9f4dbe7685c6c425e4df7a1c91e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_581d76ae58dbd000c835a73874e58c76.setContent(html_270e9f4dbe7685c6c425e4df7a1c91e9);
#
#
#
#         marker_90a220280f067cc23fb5e3de3db8eec6.bindPopup(popup_581d76ae58dbd000c835a73874e58c76)
#         ;
#
#
#
#
#             var marker_6335251f1a56457d4151ad8c5e29ced4 = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_07f23d1e15bd7ecd2d8ea23976817bfb);
#
#
#         var popup_35eeda12b79398158854d6f9ed1531fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7dee0cda3087bbcbd2ae7e7fae23c12c = $(`&lt;div id=&quot;html_7dee0cda3087bbcbd2ae7e7fae23c12c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_35eeda12b79398158854d6f9ed1531fb.setContent(html_7dee0cda3087bbcbd2ae7e7fae23c12c);
#
#
#
#         marker_6335251f1a56457d4151ad8c5e29ced4.bindPopup(popup_35eeda12b79398158854d6f9ed1531fb)
#         ;
#
#
#
#
#             var marker_5c74651310068ce73751368e49be7134 = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1030-azure
# Datetime: 2025-09-22 12:01:52
# Python Version: 3.11.13
# -----------------------------------
